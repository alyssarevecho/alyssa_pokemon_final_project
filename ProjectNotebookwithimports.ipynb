# %% [markdown]
# # Quiz: How Well Do You Know Pokemon?

# %% [markdown]
# Alyssa Nicole Revecho

# %% [markdown]
# December 9th, 2020

# %% [markdown]
# ## Overview

# %% [markdown]
# For my COGS18 final project, I have decided to construct a light hearted quiz to relax us all from the stressors during finals week. Growing up, I have always had a facination with creating my own quizzes, therefore I thought the perfect challenge for me to take on would be to code my very own quiz! Yes I know, many of us are not Pokemon fans--but it sure is worth a shot! I picked Pokemon as my quiz topic because it is something that has been fuleing my happiness latley in my downtime amidst the chaos in the world. Best of luck!

# %% [markdown]
# ## Process

# %% [markdown]
# This coding process uses classes, documentation, loops, conditionals, functions and variables. This code is constructed to distribute a quiz consisting of 10 random questions. One point is added to your score as you answer the questions correctly choosing from "A", "B" and "C" for the corresponding quiz question. If you input an improper letter, you will be redirected to choose an appropriate answer choice. For each question you answer correctly, the code will output ""You got that right!", for each incorrect answer you will see an output of "That's incorrect." Scoring 0-3 questions correctly will leave you with a "You've got more training to do young grasshopper!" message. Scoring 4-6 questions correctly will leave you with a "You've got the basics, good job!" message. Lastly, scoring 7-10 questions correctly will present you with "You sure are a pokemon master!". How exciting! Whos ready to become Pokemon master!?

# %% [markdown]
# ## Instructions

# %% [markdown]
#     1.) Run the beginning 4 code cells.
#     2.) Run the 5th to play the quiz to test your Pokemon knowledge!
#     3.) Enter "A", "B" or "C" into the text box below the given question.
#     4.) Answer all 10 questions to reveal your score.

# %% [markdown]
# ## Notes for Test Functions

# %% [markdown]
# In this project notebook you will find 2 test functions, along with 1 pytest function. The two non-pytest functions can be run by running the beginning 4 code cells first. The 5th line is all yours to play!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Project Code

# %%
from my_module.classes import PokemonQuiz

# %%
from my_module.prompts import question_prompts

# %%
from my_module.answers import question_answers

# %%
from my_module.functions import poke_quiz, final_count_placement, play_quiz

# %%
play_quiz() #Will play the quiz game. Have fun!

# %%
poke_quiz(question_answers) #This will TEST that the quiz running properly with the questions and answers
# Out:
# How many Magickarp candies do you need to evolve a Gyrados in Pokemon Go?
# (a) 100
# (b) 200
# (c) 400
#
# a
# That's incorrect.
# What does a Sandshrew evolve into?
# (a) Kabutops
# (b) Sandslash
# (c) Vaporeon
#
# b
# You got that right!
# What is the name of Ash's female sidekick in the show?
# (a) Sarah
# (b) Misty
# (c) Claire
#
# c
# That's incorrect.
# What best defeats rock-type pokemon in a battle?
# (a) Steel-Type
# (b) Fighting-Type
# (c) Bug-Type
#
# a
# That's incorrect.
# What type of pokemon is Squirtle?
# (a) Fire-Type
# (b) Rock-Type
# (c) Water-Type
#
# b
# That's incorrect.
# Which of the following is not an Evee evolve form?
# (a) Jolteon
# (b) Vaporeon
# (c) Charmander
#
# c
# You got that right!
# What is the team name of the villans on the show?
# (a) Team Rocket
# (b) Team Fire
# (c) Team Spike
#
# a
# You got that right!
# What is my all time favorite pokemon?
# (a) Mewtwo
# (b) Pikachu
# (c) Squirtle
#
# c
# You got that right!
# ...

# %% [markdown]
# This test shows that the output should be a single number once we run the question and answer functions for poke_quiz.

# %%
play_quiz() #This will TEST that the quiz will output the corresponding message to your score
# Out:
# Lets see how much you know about pokemon!
# How many can you get correct?
# How many Magickarp candies do you need to evolve a Gyrados in Pokemon Go?
# (a) 100
# (b) 200
# (c) 400
#
# a
# That's incorrect.
# Who was Ash Ketchem's first pokemon?
# (a) Pikachu
# (b) Dragonite
# (c) Bulbasaur
#
# c
# That's incorrect.
# What does a Sandshrew evolve into?
# (a) Kabutops
# (b) Sandslash
# (c) Vaporeon
#
# b
# You got that right!
# What is the name of Ash's female sidekick in the show?
# (a) Sarah
# (b) Misty
# (c) Claire
#
# a
# That's incorrect.
# What type of pokemon is Squirtle?
# (a) Fire-Type
# (b) Rock-Type
# (c) Water-Type
#
# c
# You got that right!
# Which of the following is a legendary pokemon?
# (a) Lugia
# (b) Gyrados
# (c) Blastoise
#
# a
# You got that right!
# What is the team name of the villans on the show?
# (a) Team Rocket
# (b) Team Fire
# (c) Team Spike
#
# a
# You got that right!
# Which of the following is not an Evee evolve form?
# (a) Jolteon
# (b) Vaporeon
# ...

# %% [markdown]
# This test shows that the out output should give a score, along with a corresponding message.

# %%
# !pytest "my_module/test_functions.py" #This will TEST the final count placement
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.5, pytest-6.1.1, py-1.9.0, pluggy-0.13.1
# rootdir: /Users/alyssarevecho
# collected 1 item
#
# my_module/test_functions.py .                                            [100%]
#
# ============================== 1 passed in 0.01s ===============================

# %% [markdown]
# ## Extra Credit (optional)

# %% [markdown]
# I had no coding experience whatsoever prior to taking this course. I challenged myself by combinding my knowledge from multiple modules of the course to create a unique and fun approach to the final project. In additon, I feel that I challenged myself by not just simply making a quiz with a set order and standard output. Alternatively, I implemented randomized orders and a final count placement with a corresponding messagage to create a more complex game. I am very proud of myself for devoting all my free hours to this project, it was a challenging but fun learning experience!
